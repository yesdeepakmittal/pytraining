# %% [markdown]
# <a href="https://colab.research.google.com/github/yesdeepakmittal/pytraining/blob/master/Advanced/dendogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
import matplotlib.pyplot as plt
import numpy as np

# %%
df = np.array([[0.40,0.53], 
               [0.22,0.38],
               [0.35,0.32],
               [0.26,0.19],
               [0.08,0.41],
               [0.45,0.30],
               ])

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(15, 10))
dend = shc.dendrogram(shc.linkage(df, method='single'))
plt.title("Dendrogram")
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.grid(color='black', linestyle='-', linewidth=1)
