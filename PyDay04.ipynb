# %% [markdown]
# ### PRINT THE PATTERN

# %% [markdown]
# ![ques11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <p>*</p>
# <p>* *</p>
# <p>* * *</p>
# <p>* * * *</p>
# <p>* * * * *</p>

# %% [markdown]
# # 1

# %%
n = 5
for i in range(1,n+1):
  print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
n = 5
for i in range(1,n+1):
  print('* '*(i))
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n =5 
for i in range(1,n+1):
  for j in range(i):
    print('*',end = ' ')
  print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# # 2

# %%
n = 5
for i in range(n):
  print('*'*(n-i))
# Out:
# *****
# ****
# ***
# **
# *

# %%
n = 5
for i in range(n):
  print('* '*(n-i))
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 5
for i in range(n):
  for j in range(n-i):
    print('*',end = ' ')
  print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# # 3

# %%
n = 5
for i in range(n):
  print(' '*(n-i-1),'*'*(i+1))
# Out:
#      *
#     **
#    ***
#   ****
#  *****

# %%
n = 5
for i in range(5):
  print(' '*(2*(n-i+1)),end = '')
  for j in range(i+1):
    print('*',end = ' ')
  print()
# Out:
#             *
#           * *
#         * * *
#       * * * *
#     * * * * *

# %% [markdown]
# # 4

# %%
n = 5
for i in range(n):
  print(' '*(n-i-1),end = '')
  for j in range(i+1):
    print('*',end= ' ')
  print()
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
